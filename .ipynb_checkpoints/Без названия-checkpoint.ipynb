# %%
import pandas as pd

# %%
contests = pd.read_csv("convertcsv.csv")

# %%
contests
# Out:
#      id_competition  id_fight  id_person_blue  id_person_white  id_winner  \
# 0              1527    363610            2673            10710       2673
# 1              1555    363140           13763             8652       8652
# 2              1577    383335            9904            12367      12367
# 3              1448    321375            2673              925       2673
# 4              1715    450501           12236             2673       2673
# ..              ...       ...             ...              ...        ...
# 345            1601    435710             285            19169        285
# 346            1586    437636           28416            34569      34569
# 347            1726    465336           52221            34736      52221
# 348            1759    490587           15224            37516      15224
# 349            1736    495982           49961            40370      40370
#
#      is_finished  round  duration  ippon  waza  ...  country_short_blue  \
# ...

# %%
calc_data = contests[["id_person_blue", "id_person_white", "id_winner", "competition_date"]]
calc_data
# Out:
#      id_person_blue  id_person_white  id_winner competition_date
# 0              2673            10710       2673       2017-11-18
# 1             13763             8652       8652       2017-11-11
# 2              9904            12367      12367       2018-04-06
# 3              2673              925       2673       2017-03-11
# 4             12236             2673       2673       2019-03-09
# ..              ...              ...        ...              ...
# 345             285            19169        285       2018-11-23
# 346           28416            34569      34569       2018-12-01
# 347           52221            34736      52221       2019-04-20
# 348           15224            37516      15224       2019-07-18
# 349           49961            40370      40370       2019-08-03
#
# [350 rows x 4 columns]

# %%
import requests

# %% [raw]
# res = requests.get("https://data.ijf.org/api/get_json?access_token=&params%5Baction%5D=contest.find&params%5B__ust%5D=&params%5Bid_weight%5D=6&params%5Byear%5D=2023&params%5Blimit%5D=1000&params%5Border_by%5D=competition_date", verify=False)
